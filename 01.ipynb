# %% [markdown]
# <a href="https://colab.research.google.com/github/ananyakbcodes/TEAM_PROJECT/blob/Aaliyah/01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ananyakbcodes/TEAM_PROJECT.git
# Out:
# Cloning into 'TEAM_PROJECT'...
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (4/4), done.
# Receiving objects: 100% (10/10), done.
# remote: Total 10 (delta 0), reused 3 (delta 0), pack-reused 0 (from 0)
